# %%
#some magicto show the images inside the notebook
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %matplotlib inline
import numpy as np
import cv2
from matplotlib import pyplot as plt
from mrf import MRFStereo, read_data
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
left = "tsukuba-imL.png"
right = "tsukuba-imR.png"
imgL = cv2.imread(left,0)
imgR = cv2.imread(right,0)

stereo = cv2.StereoBM_create(16,5)

disparity = stereo.compute(imgL, imgR)

plt.imshow(disparity,'gray')
plt.show()

# %%
mrf2 = MRFStereo(
    dict(
        LAMBDA=20,
        SMOOTHNESS_TRUNC=2,
        squared=False
    )
)

initial_image = mrf2.show()

# %%
filtered_image = mrf2.run(30, verbose=True)
# Out:
# iteration 1 / 30, energy = 3000702
# iteration 2 / 30, energy = 2975342
# iteration 3 / 30, energy = 2968583
# iteration 4 / 30, energy = 2966063
# iteration 5 / 30, energy = 2965383
# iteration 6 / 30, energy = 2964583
# iteration 7 / 30, energy = 2963983
# iteration 8 / 30, energy = 2963823
# iteration 9 / 30, energy = 2963663
# iteration 10 / 30, energy = 2963863
# iteration 11 / 30, energy = 2964103
# iteration 12 / 30, energy = 2964063
# iteration 13 / 30, energy = 2963983
# iteration 14 / 30, energy = 2963983
# iteration 15 / 30, energy = 2963583
# iteration 16 / 30, energy = 2963383
# iteration 17 / 30, energy = 2963383
# iteration 18 / 30, energy = 2963303
# iteration 19 / 30, energy = 2963463
# iteration 20 / 30, energy = 2963583
# iteration 21 / 30, energy = 2963503
# iteration 22 / 30, energy = 2963503
# iteration 23 / 30, energy = 2963463
# iteration 24 / 30, energy = 2963463
# iteration 25 / 30, energy = 2963463
# iteration 26 / 30, energy = 2963463
# iteration 27 / 30, energy = 2963463
# iteration 28 / 30, energy = 2963463
# iteration 29 / 30, energy = 2963463
# iteration 30 / 30, energy = 2963463

# %%
plt.imshow(cv2.medianBlur(disparity, 5), 'gray')

# %%
mine = ((img_depth)*256/16).astype(int)
