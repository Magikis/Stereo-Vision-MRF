# %%
#some magicto show the images inside the notebook
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %matplotlib inline
import numpy as np
import cv2
from matplotlib import pyplot as plt
from mrf import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
left = "tsukuba-imL.png"
right = "tsukuba-imR.png"
imgL = cv2.imread(left,0)
imgR = cv2.imread(right,0)

stereo = cv2.StereoBM_create(16,5)

disparity = stereo.compute(imgL, imgR)

plt.imshow(disparity,'gray')
plt.show()

# %%
mrf2 = MRFStereo(*read_data(), init='cv')
initial_image = mrf2.show()

# %%
filtered_image = mrf2.run(30, verbose=True)
# Out:
# iteration 1 / 30, energy = 9686412
# iteration 2 / 30, energy = 7702018
# iteration 3 / 30, energy = 6584822
# iteration 4 / 30, energy = 6104022
# iteration 5 / 30, energy = 5923222
# iteration 6 / 30, energy = 5834420
# iteration 7 / 30, energy = 5794620
# iteration 8 / 30, energy = 5789420
# iteration 9 / 30, energy = 5777820
# iteration 10 / 30, energy = 5772820
# iteration 11 / 30, energy = 5772620
# iteration 12 / 30, energy = 5774420
# iteration 13 / 30, energy = 5768420
# iteration 14 / 30, energy = 5772420
# iteration 15 / 30, energy = 5772420
# iteration 16 / 30, energy = 5771420
# iteration 17 / 30, energy = 5776420
# iteration 18 / 30, energy = 5776220
# iteration 19 / 30, energy = 5777020
# iteration 20 / 30, energy = 5778820
# iteration 21 / 30, energy = 5780020
# iteration 22 / 30, energy = 5779020
# iteration 23 / 30, energy = 5783420
# iteration 24 / 30, energy = 5781420
# iteration 25 / 30, energy = 5786220
# iteration 26 / 30, energy = 5788620
# iteration 27 / 30, energy = 5791220
# iteration 28 / 30, energy = 5792420
# iteration 29 / 30, energy = 5794020
# iteration 30 / 30, energy = 5794820

# %%
plt.imshow(cv2.medianBlur(disparity, 5), 'gray')

# %%
mine = ((img_depth)*256/16).astype(int)
